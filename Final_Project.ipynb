# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
import pandas as pd

# %%
# loading the dataset
df = pd.read_csv('/content/onlinedeliverydata.csv')
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  Pin code         Medium (P1)  \
# 0                Post Graduate            4    560001  Food delivery apps
# 1                     Graduate            3    560009  Food delivery apps
# ...

# %% [markdown]
# # Pre-Processing

# %%
# dataset info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 48 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Age                                        388 non-null    int64
#  1   Gender                                     388 non-null    object
#  2   Marital Status                             388 non-null    object
#  3   Occupation                                 388 non-null    object
#  4   Monthly Income                             388 non-null    object
#  5   Educational Qualifications                 388 non-null    object
#  6   Family size                                388 non-null    int64
#  7   Pin code                                   388 non-null    int64
#  8   Medium (P1)                                388 non-null    object
#  9   Medium (P2)                                388 non-null    object
# ...

# %%
# describe
df.describe()
# Out:
#               Age  Family size       Pin code
# count  388.000000   388.000000     388.000000
# mean    24.628866     3.280928  560040.113402
# std      2.975593     1.351025      31.399609
# min     18.000000     1.000000  560001.000000
# 25%     23.000000     2.000000  560010.750000
# 50%     24.000000     3.000000  560033.500000
# 75%     26.000000     4.000000  560068.000000
# max     33.000000     6.000000  560109.000000

# %%
# displaying rows and columns
df.shape
# Out:
# (388, 48)

# %%
# finding null values

df.isnull().sum()
# Out:
# Age                                          0
# Gender                                       0
# Marital Status                               0
# Occupation                                   0
# Monthly Income                               0
# Educational Qualifications                   0
# Family size                                  0
# Pin code                                     0
# Medium (P1)                                  0
# Medium (P2)                                  0
# Meal(P1)                                     0
# Meal(P2)                                     0
# Perference(P1)                               0
# Perference(P2)                               0
# Ease and convenient                          0
# Time saving                                  0
# More restaurant choices                      0
# Easy Payment option                          0
# More Offers and Discount                     0
# Good Food quality                            0
# ...

# %% [markdown]
# # EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# distribution of numeric columns

plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.histplot(df['Age'],color='orange',kde=True)
plt.subplot(2,2,2)
sns.histplot(df['Family size'],color='orange',kde=True)
plt.subplot(2,2,3)
sns.boxplot(data=df,x='Age',color='orange')
plt.subplot(2,2,4)
sns.boxplot(data=df,x='Family size',color='orange')
plt.show()

# %% [markdown]
# # Correlation between Monthly Income and Educational Qualification

# %%
import matplotlib.pyplot as plt


x = df['Educational Qualifications']
y = df['Monthly Income']

plt.figure(figsize=(8, 6))
plt.scatter(x, y, alpha=0.7, color='skyblue', edgecolor='black')
plt.title('Scatter Plot: Income vs Qualification')
plt.xlabel('Educational Qualification')
plt.ylabel('Monthly Income')
plt.grid(True)
plt.show()

# %% [markdown]
# # Count of categorical data

# %%
plt.figure(figsize=(30,10))
plt.subplot(2,3,1)
sns.countplot(data=df, x='Gender')
plt.subplot(2,3,2)
sns.countplot(data=df, x='Marital Status')
plt.subplot(2,3,3)
sns.countplot(data=df, x='Occupation')
plt.subplot(2,3,4)
sns.countplot(data=df, x='Monthly Income')
plt.subplot(2,3,5)
sns.countplot(data=df, x='Educational Qualifications')
plt.subplot(2,3,6)
sns.countplot(data=df, x='Family size')
plt.show()

# %% [markdown]
# # Food perference of the customers

# %%
plt.figure(figsize=(30,10))
plt.subplot(2,3,1)
sns.countplot(data=df, x='Medium (P1)')
plt.subplot(2,3,2)
sns.countplot(data=df, x='Medium (P2)')
plt.subplot(2,3,3)
sns.countplot(data=df, x='Meal(P1)')
plt.subplot(2,3,4)
sns.countplot(data=df, x='Meal(P2)')
plt.subplot(2,3,5)
sns.countplot(data=df, x='Perference(P1)')
plt.xticks(rotation = 60)
plt.subplot(2,3,6)
sns.countplot(data=df, x='Perference(P2)')
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# # Influence of positive factors on the customers

# %%
plt.figure(figsize=(20,10))
plt.subplot(3,4,1)
ease = df['Ease and convenient'].value_counts()
plt.pie(x=ease, labels=ease.index,autopct='%1.1f%%',explode=[0.2,0,0,0,0])
plt.xticks(rotation=60)
plt.title('Ease and Convenient')
plt.subplot(3,4,2)
time_saved = df['Time saving'].value_counts()
plt.pie(x=time_saved, labels=time_saved.index,autopct='%1.1f%%',explode=[0.2,0,0,0,0])
plt.xticks(rotation=60)
plt.title('Time Saved')
plt.subplot(3,4,3)
restaurant = df['More restaurant choices'].value_counts()
plt.pie(x=restaurant, labels=restaurant.index,autopct='%1.1f%%',explode=[0.2,0,0,0,0])
plt.xticks(rotation=60)
plt.title('More restaurant choices')
plt.subplot(3,4,4)
offers_discount = df['More Offers and Discount'].value_counts()
plt.pie(x=offers_discount, labels=offers_discount.index,autopct='%1.1f%%',explode=[0.2,0,0,0,0])
plt.xticks(rotation=60)
plt.title('More offers and discounts')
plt.subplot(3,4,5)
payment = df['Easy Payment option'].value_counts()
plt.pie(x=payment, labels=payment.index,autopct='%1.1f%%',explode=[0.2,0,0,0,0])
plt.xticks(rotation=60)
plt.title('Easy payment option')
plt.subplot(3,4,6)
food_quality = df['Good Food quality'].value_counts()
plt.pie(x=food_quality, labels=food_quality.index,autopct='%1.1f%%',explode=[0.2,0,0,0,0])
plt.xticks(rotation=60)
plt.title('Quality of food')
plt.subplot(3,4,7)
tracking_system = df['Good Tracking system'].value_counts()
plt.pie(x=tracking_system, labels=tracking_system.index,autopct='%1.1f%%',explode=[0.2,0,0,0,0])
plt.xticks(rotation=60)
plt.title('Tracking System')
plt.subplot(3,4,8)
influence = df['Influence of rating'].value_counts()
plt.pie(x=influence, labels=influence.index,autopct='%1.1f%%',explode=[0.2,0,0])
plt.xticks(rotation=60)
plt.title('Rating')
plt.subplot(3,4,9)
output = df['Output'].value_counts()
plt.pie(x=output, labels=output.index,autopct='%1.1f%%',explode=[0.2,0])
plt.xticks(rotation=60)
plt.title('Output')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Influence of negative factors on the customers

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,4,1)
sns.countplot(data=df,x='Health Concern')
plt.xticks(rotation=60)
plt.subplot(2,4,2)
sns.countplot(data=df,x='Late Delivery')
plt.xticks(rotation=60)
plt.subplot(2,4,3)
sns.countplot(data=df,x='Poor Hygiene')
plt.xticks(rotation=60)
plt.subplot(2,4,4)
sns.countplot(data=df,x='Bad past experience')
plt.xticks(rotation=60)
plt.subplot(2,4,5)
sns.countplot(data=df,x='Unavailability')
plt.xticks(rotation=60)
plt.subplot(2,4,6)
sns.countplot(data=df,x='Unaffordable')
plt.xticks(rotation=60)
plt.subplot(2,4,7)
sns.countplot(data=df,x='Delay of delivery person getting assigned')
plt.xticks(rotation=60)
plt.subplot(2,4,8)
sns.countplot(data=df,x='Delay of delivery person picking up food')
plt.xticks(rotation=60)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Wordcloud of positive features

# %%
from wordcloud import WordCloud

# List of features
pos_features = [
    'Ease and convenient', 'Time saving', 'More restaurant choices',
    'More Offers and Discount', 'Easy Payment option', 'Good Food quality',
    'Good Tracking system', 'Influence of rating'
]

# Convert the list into a single string (word cloud needs text input)
features_text = " ".join(pos_features)

# Generate the word cloud
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    colormap='viridis',
    random_state=42
).generate(features_text)

# Plot the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis
plt.title("Word Cloud of Positve Features", fontsize=16)
plt.show()

# %% [markdown]
# # WordCloud of negative features

# %%
# Import necessary libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# List of features
neg_features = [
    'Health Concern','Late Delivery','Poor Hygiene','Bad past experience'
    'Unavailability','Unaffordable','Delay of delivery person getting assigned',
    'Delay of delivery person picking up food'
]

# Convert the list into a single string (word cloud needs text input)
features_text = " ".join(neg_features)

# Generate the word cloud
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    colormap='viridis',
    random_state=42
).generate(features_text)

# Plot the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis
plt.title("Word Cloud of Negative Features", fontsize=16)
plt.show()

# %% [markdown]
# # Heat Map of Correlation Matrix

# %%
# Convert categorical values to numeric
response_map = {
    'Strongly disagree': 1,
    'Disagree': 2,
    'Neutral': 3,
    'Agree': 4,
    'Strongly agree': 5,
    'Yes': 1,
    'No': 0,
    'Maybe': 0.5
}

# Select the columns for correlation
columns_of_interest = [
    'Ease and convenient',
    'Time saving',
    'More restaurant choices',
    'More Offers and Discount',
    'Easy Payment option',
    'Good Food quality',
    'Good Tracking system',


]


corr_df = df[columns_of_interest].copy()


for column in corr_df.columns:
    corr_df[column] = corr_df[column].map(response_map)


correlation_matrix = corr_df.corr()


plt.figure(figsize=(12, 10))

# Create heatmap
sns.heatmap(correlation_matrix,
            annot=True,
            cmap='coolwarm',
            center=0,
            vmin=-1, vmax=1,
            fmt='.2f',
            square=True)

plt.title('Correlation Matrix of Food Delivery App Features', pad=20)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)


plt.tight_layout()


plt.show()

# Print the correlation values
print("\nCorrelation Matrix Values:")
print(correlation_matrix.round(2))

# Find strongest positive correlations
positive_corr = []
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        if correlation_matrix.iloc[i,j] > 0.5:
            positive_corr.append((
                correlation_matrix.index[i],
                correlation_matrix.columns[j],
                correlation_matrix.iloc[i,j]
            ))

print("\nStrongest Positive Correlations (>0.5):")
for item in sorted(positive_corr, key=lambda x: x[2], reverse=True):
    print(f"{item[0]} & {item[1]}: {item[2]:.2f}")

# Find strongest negative correlations
negative_corr = []
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        if correlation_matrix.iloc[i,j] < -0.5:
            negative_corr.append((
                correlation_matrix.index[i],
                correlation_matrix.columns[j],
                correlation_matrix.iloc[i,j]
            ))

print("\nStrongest Negative Correlations (<-0.5):")
for item in sorted(negative_corr, key=lambda x: x[2]):
    print(f"{item[0]} & {item[1]}: {item[2]:.2f}")

# Calculate and print average correlation for each feature
print("\nAverage Correlation of Each Feature:")
avg_corr = correlation_matrix.mean()
for feature, avg in avg_corr.sort_values(ascending=False).items():
    print(f"{feature}: {avg:.2f}")
# Out:
# Correlation Matrix Values:
#                           Ease and convenient  Time saving  \
# Ease and convenient                      1.00         0.67
# Time saving                              0.67         1.00
# More restaurant choices                  0.67         0.60
# More Offers and Discount                 0.62         0.50
# Easy Payment option                      0.65         0.61
# Good Food quality                        0.44         0.49
# Good Tracking system                     0.49         0.48
#
#                           More restaurant choices  More Offers and Discount  \
# Ease and convenient                          0.67                      0.62
# Time saving                                  0.60                      0.50
# More restaurant choices                      1.00                      0.59
# More Offers and Discount                     0.59                      1.00
# Easy Payment option                          0.66                      0.66
# ...

# %% [markdown]
# # Label Encoding the positive factors

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder


columns_to_encode = [
    'Ease and convenient',
    'Time saving',
    'More restaurant choices',
    'More Offers and Discount',
    'Easy Payment option',
    'Good Food quality',
    'Good Tracking system',
    'Influence of rating',
    'Output'
]


label_encoder = LabelEncoder()


for column in columns_to_encode:
    df[column] = label_encoder.fit_transform(df[column].astype(str))


print(df[columns_to_encode].head())
# Out:
#    Ease and convenient  Time saving  More restaurant choices  \
# 0                    2            2                        2
# 1                    3            3                        3
# 2                    3            3                        3
# 3                    0            0                        3
# 4                    0            0                        0
#
#    More Offers and Discount  Easy Payment option  Good Food quality  \
# 0                         2                    2                  2
# 1                         3                    3                  2
# 2                         2                    2                  1
# 3                         3                    0                  0
# 4                         0                    0                  2
#
#    Good Tracking system  Influence of rating  Output
# 0                     2                    2       1
# 1                     0                    2       1
# ...

# %% [markdown]
# # SMOTE Analysis on Ouput Column

# %%
from imblearn.over_sampling import SMOTE
import pandas as pd

# Define your features and target variable
x = df[['Ease and convenient', 'Time saving', 'More restaurant choices', 'More Offers and Discount',
        'Easy Payment option', 'Good Food quality', 'Good Tracking system', 'Influence of rating']]
y = df['Output']

# Ensure features are numeric
if not x.select_dtypes(include=['number']).shape[1] == x.shape[1]:
    raise ValueError("All features must be numeric. Please encode categorical features before applying SMOTE.")

# Apply SMOTE
smote = SMOTE(random_state=42)
X_smote, Y_smote = smote.fit_resample(x, y)

# Check class distribution before and after SMOTE
print("Class distribution before SMOTE:")
print(y.value_counts())

print("\nClass distribution after SMOTE:")
print(pd.Series(Y_smote).value_counts())
# Out:
# Class distribution before SMOTE:
# Output
# 1    301
# 0     87
# Name: count, dtype: int64
#
# Class distribution after SMOTE:
# Output
# 1    301
# 0    301
# Name: count, dtype: int64

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Logistic Regression

# %%
# Import necessary libraries
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define your features and target variable
x = df[['Ease and convenient', 'Time saving', 'More restaurant choices', 'More Offers and Discount',
        'Easy Payment option', 'Good Food quality', 'Good Tracking system', 'Influence of rating']]
y = df['Output']


# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42, stratify=y)

# Apply SMOTE on the training data
smote = SMOTE(random_state=42)
X_train_smote, Y_train_smote = smote.fit_resample(X_train, Y_train)

# Build the logistic regression model
log_reg = LogisticRegression(random_state=42, max_iter=500)  # Increased max_iter for convergence
log_reg.fit(X_train_smote, Y_train_smote)

# Make predictions
Y_pred = log_reg.predict(X_test)

# Evaluate the model
print("Confusion Matrix:")
cm = confusion_matrix(Y_test, Y_pred)
print(cm)

print("\nClassification Report:")
print(classification_report(Y_test, Y_pred))

print("\nAccuracy Score:")
print(accuracy_score(Y_test, Y_pred))

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=log_reg.classes_, yticklabels=log_reg.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Confusion Matrix:
# [[13 13]
#  [31 60]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.30      0.50      0.37        26
#            1       0.82      0.66      0.73        91
#
#     accuracy                           0.62       117
#    macro avg       0.56      0.58      0.55       117
# weighted avg       0.70      0.62      0.65       117
#
#
# Accuracy Score:
# 0.6239316239316239

# %% [markdown]
# # Random Forest Classification

# %%
# Import necessary libraries
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define your features and target variable
x = df[['Ease and convenient', 'Time saving', 'More restaurant choices', 'More Offers and Discount',
        'Easy Payment option', 'Good Food quality', 'Good Tracking system', 'Influence of rating']]
y = df['Output']

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42, stratify=y)

# Apply SMOTE on the training data
smote = SMOTE(random_state=42)
X_train_smote, Y_train_smote = smote.fit_resample(X_train, Y_train)

# Build the Random Forest Classifier
rf_clf = RandomForestClassifier(random_state=42, n_estimators=100)  # Default n_estimators=100
rf_clf.fit(X_train_smote, Y_train_smote)

# Make predictions
Y_pred = rf_clf.predict(X_test)

# Evaluate the model
print("Confusion Matrix:")
cm = confusion_matrix(Y_test, Y_pred)
print(cm)

print("\nClassification Report:")
print(classification_report(Y_test, Y_pred))

print("\nAccuracy Score:")
print(accuracy_score(Y_test, Y_pred))

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=rf_clf.classes_, yticklabels=rf_clf.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Confusion Matrix:
# [[22  4]
#  [11 80]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.85      0.75        26
#            1       0.95      0.88      0.91        91
#
#     accuracy                           0.87       117
#    macro avg       0.81      0.86      0.83       117
# weighted avg       0.89      0.87      0.88       117
#
#
# Accuracy Score:
# 0.8717948717948718

# %% [markdown]
# # Decision Tree Classifier

# %%
# Import necessary libraries
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define your features and target variable
x = df[['Ease and convenient', 'Time saving', 'More restaurant choices', 'More Offers and Discount',
        'Easy Payment option', 'Good Food quality', 'Good Tracking system', 'Influence of rating']]
y = df['Output']

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42, stratify=y)

# Apply SMOTE on the training data
smote = SMOTE(random_state=42)
X_train_smote, Y_train_smote = smote.fit_resample(X_train, Y_train)

# Build the Decision Tree Classifier
dt_clf = DecisionTreeClassifier(random_state=42)
dt_clf.fit(X_train_smote, Y_train_smote)

# Make predictions
Y_pred = dt_clf.predict(X_test)

# Evaluate the model
print("Confusion Matrix:")
cm = confusion_matrix(Y_test, Y_pred)
print(cm)

print("\nClassification Report:")
print(classification_report(Y_test, Y_pred))

print("\nAccuracy Score:")
print(accuracy_score(Y_test, Y_pred))

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=dt_clf.classes_, yticklabels=dt_clf.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Confusion Matrix:
# [[18  8]
#  [ 6 85]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.69      0.72        26
#            1       0.91      0.93      0.92        91
#
#     accuracy                           0.88       117
#    macro avg       0.83      0.81      0.82       117
# weighted avg       0.88      0.88      0.88       117
#
#
# Accuracy Score:
# 0.8803418803418803

# %% [markdown]
# # Support Vector Machine(SVM)

# %%
# Import necessary libraries
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define your features and target variable
x = df[['Ease and convenient', 'Time saving', 'More restaurant choices', 'More Offers and Discount',
        'Easy Payment option', 'Good Food quality', 'Good Tracking system', 'Influence of rating']]
y = df['Output']


# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42, stratify=y)

# Apply SMOTE on the training data
smote = SMOTE(random_state=42)
X_train_smote, Y_train_smote = smote.fit_resample(X_train, Y_train)

# Standardize the features (SVM works better with standardized data)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_smote = scaler.fit_transform(X_train_smote)
X_test = scaler.transform(X_test)

# Build the SVM model
svm_clf = SVC(kernel='linear', random_state=42)  # Using linear kernel; adjust if needed
svm_clf.fit(X_train_smote, Y_train_smote)

# Make predictions
Y_pred = svm_clf.predict(X_test)

# Evaluate the model
print("Confusion Matrix:")
cm = confusion_matrix(Y_test, Y_pred)
print(cm)

print("\nClassification Report:")
print(classification_report(Y_test, Y_pred))

print("\nAccuracy Score:")
print(accuracy_score(Y_test, Y_pred))

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=svm_clf.classes_, yticklabels=svm_clf.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Confusion Matrix:
# [[16 10]
#  [47 44]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.25      0.62      0.36        26
#            1       0.81      0.48      0.61        91
#
#     accuracy                           0.51       117
#    macro avg       0.53      0.55      0.48       117
# weighted avg       0.69      0.51      0.55       117
#
#
# Accuracy Score:
# 0.5128205128205128

# %% [markdown]
# # Gradient Boost Classifier

# %%
# Import necessary libraries
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define your features and target variable
x = df[['Ease and convenient', 'Time saving', 'More restaurant choices', 'More Offers and Discount',
        'Easy Payment option', 'Good Food quality', 'Good Tracking system', 'Influence of rating']]
y = df['Output']


# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42, stratify=y)

# Apply SMOTE on the training data
smote = SMOTE(random_state=42)
X_train_smote, Y_train_smote = smote.fit_resample(X_train, Y_train)

# Build the Gradient Boosting Classifier
gb_clf = GradientBoostingClassifier(random_state=42)
gb_clf.fit(X_train_smote, Y_train_smote)

# Make predictions
Y_pred = gb_clf.predict(X_test)

# Evaluate the model
print("Confusion Matrix:")
cm = confusion_matrix(Y_test, Y_pred)
print(cm)

print("\nClassification Report:")
print(classification_report(Y_test, Y_pred))

print("\nAccuracy Score:")
print(accuracy_score(Y_test, Y_pred))

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=gb_clf.classes_, yticklabels=gb_clf.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Confusion Matrix:
# [[23  3]
#  [12 79]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.66      0.88      0.75        26
#            1       0.96      0.87      0.91        91
#
#     accuracy                           0.87       117
#    macro avg       0.81      0.88      0.83       117
# weighted avg       0.90      0.87      0.88       117
#
#
# Accuracy Score:
# 0.8717948717948718

# %% [markdown]
# # Text Analysis

# %%
# copying the dataset

df1 = df.copy()

#removing irrelevant reviews- Nil value
df1= df[~df['Reviews'].isin(['NIL','nil','Nil','No','Nil\n'])]

# considering the two columns
df1=df1[['Reviews','Output']]
df1
# Out:
#                                                Reviews  Output
# 2    Many a times payment gateways are an issue, so...       1
# 11   Language barrier is also one major issue. Mosl...       1
# 17          Spillage, bad packaging and missing items        1
# 18   Once my order from kfc got exchanged with some...       1
# 22   I feel Swiggy has a good interface for users a...       1
# ..                                                 ...     ...
# 375            I had bad quality order delivered twice       0
# 376  Bad rating doesn't mean that the food tastes b...       1
# 377            Order delivered to my location are late       0
# 378  My location is pretty well built for food deli...       1
# 386  Language barrier is also one major issue. Mosl...       1
#
# [243 rows x 2 columns]

# %% [markdown]
# # N-gram Analysis(Uni-gram, Bi-gram and Tri-gram)

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter
import re
import matplotlib.pyplot as plt

# %%
# Download required resources
import nltk
from nltk.util import ngrams
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')

# Preprocessing function
def preprocess(text):
    text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove special characters
    text = text.lower()  # Convert to lowercase
    tokens = word_tokenize(text)  # Tokenize
    stop_words = set(stopwords.words('english'))  # Load stopwords
    tokens = [word for word in tokens if word not in stop_words]  # Remove stopwords
    return tokens

# Apply preprocessing to the Reviews column
df['Tokenized_Reviews'] = df['Reviews'].fillna('').apply(preprocess)

# Function to generate N-grams and their frequencies
def generate_ngrams(tokens_list, n):
    all_ngrams = [ngrams(tokens, n) for tokens in tokens_list]  # Generate N-grams for each tokenized review
    flat_ngrams = [item for sublist in all_ngrams for item in sublist]  # Flatten the list of lists
    return Counter(flat_ngrams)  # Count frequencies

# Generate unigrams, bigrams, and trigrams
unigrams = generate_ngrams(df['Tokenized_Reviews'], 1)
bigrams = generate_ngrams(df['Tokenized_Reviews'], 2)
trigrams = generate_ngrams(df['Tokenized_Reviews'], 3)

# Function to plot N-gram frequencies
def plot_ngrams(ngram_counter, title, top_n=10):
    most_common = ngram_counter.most_common(top_n)  # Get the top N most common N-grams
    ngrams_list, counts = zip(*most_common)
    ngrams_list = [' '.join(ngram) for ngram in ngrams_list]  # Join tuples into strings
    plt.figure(figsize=(10, 6))
    plt.bar(ngrams_list, counts, color='skyblue')
    plt.title(title)
    plt.ylabel("Frequency")
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# Plot top 10 unigrams, bigrams, and trigrams
plot_ngrams(unigrams, "Top 10 Unigrams", top_n=10)
plot_ngrams(bigrams, "Top 10 Bigrams", top_n=10)
plot_ngrams(trigrams, "Top 10 Trigrams", top_n=10)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# # Sentiment Count

# %%
# !pip install textblob
from textblob import TextBlob

# Handle missing values in the Reviews column
df['Reviews'] = df['Reviews'].fillna('')

# Function to calculate sentiment polarity
def get_sentiment_polarity(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity

# Function to calculate sentiment subjectivity
def get_sentiment_subjectivity(text):
    blob = TextBlob(text)
    return blob.sentiment.subjectivity

# Apply sentiment analysis
df['Polarity'] = df['Reviews'].apply(get_sentiment_polarity)
df['Subjectivity'] = df['Reviews'].apply(get_sentiment_subjectivity)

# Classify reviews based on polarity
def classify_sentiment(polarity):
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

df['Sentiment'] = df['Polarity'].apply(classify_sentiment)

# Display sentiment counts
sentiment_counts = df['Sentiment'].value_counts()
print("Sentiment Counts:\n", sentiment_counts)

# Plot sentiment distribution
plt.figure(figsize=(8, 5))
sentiment_counts.plot(kind='bar', color=['orange', 'green', 'red'])
plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# Save results to a new CSV file
df.to_csv('reviews_with_sentiment.csv', index=False)
print("Sentiment analysis results saved to 'reviews_with_sentiment.csv'")
# Out:
# ...
# Sentiment Counts:
#  Sentiment
# Neutral     193
# Positive    136
# Negative     59
# Name: count, dtype: int64
# Sentiment analysis results saved to 'reviews_with_sentiment.csv'

# %% [markdown]
# # Sentiment Analysis for user inputs

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from imblearn.over_sampling import SMOTE
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
from sklearn.metrics import accuracy_score
import nltk

# Download necessary NLTK resources
nltk.download('wordnet')
nltk.download('stopwords')

# Load the data
file_path = '/content/onlinedeliverydata.csv'  # Corrected file path for Colab


# Extract relevant columns
data_cleaned = df[['Reviews', 'Output']].dropna()

# Preprocessing function
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = ' '.join([lemmatizer.lemmatize(word) for word in text.split() if word not in stop_words])  # Lemmatize
    return text

# Apply preprocessing to the reviews
data_cleaned['Reviews'] = data_cleaned['Reviews'].apply(preprocess_text)

# Split the data into features and target variable
x = data_cleaned['Reviews']
y = data_cleaned['Output']

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=100)

# Vectorize the text using TF-IDF
vectorizer = TfidfVectorizer(stop_words='english', lowercase=True)
x_train_vec = vectorizer.fit_transform(x_train)
x_test_vec = vectorizer.transform(x_test)

# Handle class imbalance using SMOTE (Synthetic Minority Over-sampling Technique)
smote = SMOTE(random_state=42)
x_train_vec, y_train = smote.fit_resample(x_train_vec, y_train)

# Train the Naive Bayes model with hyperparameter tuning (alpha=0.5)
model = MultinomialNB(alpha=0.5)
model.fit(x_train_vec, y_train)

# Evaluate the model with accuracy score
y_pred = model.predict(x_test_vec)
print(f"Accuracy on Test Set: {accuracy_score(y_test, y_pred):.2f}")

# Cross-validation to evaluate the model's performance
cv_scores = cross_val_score(model, x_train_vec, y_train, cv=5)
print(f"Cross-Validation Accuracy: {cv_scores.mean():.2f}")

# Interactive prediction
while True:
    user_input = input("\nEnter a comment to analyze sentiment (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break
    user_input_vec = vectorizer.transform([user_input])
    prediction = model.predict(user_input_vec)
    print(f"Predicted Sentiment: {prediction[0]}")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Accuracy on Test Set: 0.91
# Cross-Validation Accuracy: 0.87
#
# Enter a comment to analyze sentiment (or type 'exit' to quit): fast delivery
# Predicted Sentiment: 1
#
# Enter a comment to analyze sentiment (or type 'exit' to quit): bad taste
# Predicted Sentiment: 1
#
# Enter a comment to analyze sentiment (or type 'exit' to quit): quit
# Predicted Sentiment: 0
#
# Enter a comment to analyze sentiment (or type 'exit' to quit): exit

# %% [markdown]
# # Sentiment Analysis using Gradio

# %%
# !pip install --upgrade gradio
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from imblearn.over_sampling import SMOTE
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
from sklearn.metrics import accuracy_score
import gradio as gr

# Load the data
file_path = '/content/onlinedeliverydata.csv'
df = pd.read_csv(file_path)

# Extract relevant columns
data_cleaned = df[['Reviews', 'Output']].dropna()

# Preprocessing function
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = ' '.join([lemmatizer.lemmatize(word) for word in text.split() if word not in stop_words])  # Lemmatize
    return text

# Apply preprocessing to the reviews
data_cleaned['Reviews'] = data_cleaned['Reviews'].apply(preprocess_text)

# Split the data into features and target variable
x = data_cleaned['Reviews']
y = data_cleaned['Output']

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=100)

# Vectorize the text using TF-IDF
vectorizer = TfidfVectorizer(stop_words='english', lowercase=True)
x_train_vec = vectorizer.fit_transform(x_train)
x_test_vec = vectorizer.transform(x_test)

# Handle class imbalance using SMOTE (Synthetic Minority Over-sampling Technique)
smote = SMOTE(random_state=42)
x_train_vec, y_train = smote.fit_resample(x_train_vec, y_train)

# Train the Naive Bayes model with hyperparameter tuning (alpha=0.5)
model = MultinomialNB(alpha=0.5)
model.fit(x_train_vec, y_train)

# Function for Gradio
def predict_sentiment(user_input):
    user_input = preprocess_text(user_input)
    user_input_vec = vectorizer.transform([user_input])
    prediction = model.predict(user_input_vec)
    return f"Predicted Sentiment: {prediction[0]}"

# Create Gradio interface
interface = gr.Interface(
    fn=predict_sentiment,
    inputs=gr.Textbox(lines=2, placeholder="Enter a comment here..."),
    outputs=gr.Textbox(label="Predicted Sentiment"),
    title="Sentiment Analysis",
    description="Enter a comment to determine whether the sentiment is positive or negative.",
)

# Launch the app
interface.launch(share=True)
# Out:
# ...
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ef429afb6dd7998e52.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ef429afb6dd7998e52.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
